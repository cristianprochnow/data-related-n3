# %% [markdown]
# # Injeção dos dados
#
# O arquivo base disponível é o *dataset* baixado diretamente do Kaggle, e nessa listagem há a informação contabilizada através da pesquisa com diversos desenvolvedores ao redor do mundo, que trabalham exclusivamente em cargos de IA/ML. Com isso em vista
